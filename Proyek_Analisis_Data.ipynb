# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** [Fiqram Faathir]
# - **Email:** [m206d4ky2266@bangkit.academy]
# - **ID Dicoding:** [fiqram_faathir_ybHJ]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# 1. Penyewaan sepeda terbanyak terjadi pada musim apa ?
# 2. Penyewaan Sepeda terbanyak terjadi saat cuaca apa ?
# 3. Pada Bulan Berapa Penyewaan Sepeda Terbanyak ?
# 4. Pada pukul berapa penyewaan sepeda yang banyak terjadi ?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import matplotlib as plt

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
#mengambil dataset bike day dan hour
data_bike_day = pd.read_csv('Bike-sharing-dataset/day.csv')
data_bike_hour = pd.read_csv('Bike-sharing-dataset/hour.csv')

# %%
#menampilkan dataset bike day
data_bike_day.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
#menampilkan dataset bike day
data_bike_hour.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ### Assessing Data

# %%
#mengecek jumlah baris dan kolom baris dan kolom pada dataset bike day
rows_data_bike_day, columns_data_bike_day = data_bike_day.shape
print(f"jumlah baris dan pada dataset bike day adalah: {rows_data_bike_day} baris, {columns_data_bike_day} kolom \n")

#mengecek jumlah baris dan kolom baris dan kolom pada dataset bike hour
rows_data_bike_hour, columns_data_bike_hour = data_bike_hour.shape
print(f"jumlah baris dan pada dataset bike hour adalah: {rows_data_bike_hour} baris, {columns_data_bike_hour} kolom \n")

#mencari nilai missing pada data_bike_day
missing_values_data_bike_day = data_bike_day.isnull()

# Menghitung jumlah nilai missing untuk setiap kolom
missing_values_count_data_bike_day = missing_values_data_bike_day.sum()

# Menampilkan jumlah nilai missing untuk setiap kolom
print("Jumlah nilai yang hilang dalam dataset bike day:")
print(missing_values_count_data_bike_day)
print('')

missing_values_data_bike_hour = data_bike_hour.isnull()

# Menghitung jumlah nilai yang hilang untuk setiap kolom
missing_values_count_data_bike_hour = missing_values_data_bike_hour.sum()

# Menampilkan jumlah nilai yang hilang untuk setiap kolom
print("Jumlah nilai yang hilang dalam dataset bike hour:")
print(missing_values_count_data_bike_hour)
print('')

# Memeriksa jumlah data yang duplikat pada dataset bike day
duplicate_count_data_bike_day = data_bike_day.duplicated().sum()
print(f"Jumlah data yang duplikat dalam dataset bike hour: {duplicate_count_data_bike_day} \n")

# Memeriksa jumlah data yang duplikat pada dataset bike hour
duplicate_count_data_bike_hour = data_bike_hour.duplicated().sum()
print(f"Jumlah data yang duplikat dalam dataset bike hour: {duplicate_count_data_bike_hour} \n")
# Out:
# jumlah baris dan pada dataset bike day adalah: 731 baris, 16 kolom
#
# jumlah baris dan pada dataset bike hour adalah: 17379 baris, 17 kolom
#
# Jumlah nilai yang hilang dalam dataset bike day:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64
#
# Jumlah nilai yang hilang dalam dataset bike hour:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64
#
# Jumlah data yang duplikat dalam dataset bike hour: 0
#
# Jumlah data yang duplikat dalam dataset bike hour: 0

# %% [markdown]
# ### Cleaning Data

# %%
# menghapus nilai yang hilang pada dataset dataset bike day
data_bike_day_cleaned = data_bike_day.dropna()
# menghapus nilai yang hilang pada dataset dataset bike hour
data_bike_hour_cleaned = data_bike_hour.dropna()

# menghapus duplikasi pada dataset bike day
data_bike_day_cleaned = data_bike_day_cleaned.drop_duplicates()
# menghapus duplikasi pada dataset bike day
data_bike_hour_cleaned = data_bike_hour_cleaned.drop_duplicates()

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
#menggabungkan data bike day dan hour
data_bike = pd.merge(data_bike_day, data_bike_hour)

#menampilkan tipe data pada dataset bike
print("Berikut dibawah ini adalah tipe data dari tiap variabel")
print(data_bike.dtypes)

print('')

season_data_bike_day = data_bike_day['season'].unique()
season_data_bike_hour = data_bike_hour['season'].unique()

print(f'Musim yang ada pada data bike day yaitu {season_data_bike_day}')
print(f'Musim yang ada pada data bike hour yaitu {season_data_bike_hour}')
# Out:
# Berikut dibawah ini adalah tipe data dari tiap variabel
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# hr              int64
# dtype: object
#
# Musim yang ada pada data bike day yaitu [1 2 3 4]
# Musim yang ada pada data bike hour yaitu [1 2 3 4]

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
# Visualisasi pertanyaan 1
# Membuat DataFrame dengan jumlah pengguna sepeda tiap musim pada bike day
data_bike_day_musim = data_bike_day.groupby('season')['cnt'].sum().reset_index()


# Membuat plot bar
plt.figure(figsize=(4, 4))
plt.bar(data_bike_day_musim['season'], data_bike_day_musim['cnt'], color=['blue', 'orange', 'red', 'green'])
plt.xlabel('Musim')
plt.ylabel('Jumlah Pengguna Sepeda day')
plt.title('Perbandingan Jumlah Pengguna Sepeda Tiap Musim (Day)')
plt.show()



# Membuat DataFrame dengan jumlah pengguna sepeda tiap musim pada bike hour
data_bike_hour_musim = data_bike_hour.groupby('season')['cnt'].sum().reset_index()


# Membuat plot bar
plt.figure(figsize=(4, 4))
plt.bar(data_bike_hour_musim['season'], data_bike_hour_musim['cnt'], color=['blue', 'orange', 'red', 'green'])
plt.xlabel('Musim')
plt.ylabel('Jumlah Pengguna Sepeda hour')
plt.title('Perbandingan Jumlah Pengguna Sepeda Tiap Musim (Day)')
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %%
# Mengelompokkan data berdasarkan bulan dan menghitung total penggunaan sepeda
penggunaan_bulanan = data_bike_day.groupby('mnth')['cnt'].sum().reset_index()

# Membuat plot garis
plt.figure(figsize=(10, 6))
plt.plot(penggunaan_bulanan['mnth'], penggunaan_bulanan['cnt'], marker='o', color='skyblue', linestyle='-')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Pengguna Sepeda')
plt.title('Penggunaan Sepeda Terbanyak di Setiap Bulan (Day)')
plt.grid(True)
plt.show()

# Mengelompokkan data berdasarkan jam dan menghitung total penggunaan sepeda
penggunaan_harian = data_bike_hour.groupby('mnth')['cnt'].sum().reset_index()

# Membuat plot garis
plt.figure(figsize=(12, 6))
plt.plot(penggunaan_harian['mnth'], penggunaan_harian['cnt'], marker='o', color='orange', linestyle='-')
plt.xlabel('Jam')
plt.ylabel('Jumlah Pengguna Sepeda')
plt.title('Penggunaan Sepeda Terbanyak di Setiap Bulan (Hour)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# 1. Dari Hasil Visualisasi pada pertanyaan 1 didapatkan bahwa pada data bike dan hour mempunyai data yang sama yaitu pengunaan terbanyak terdapat pada musim 3 dan terendah pada musim 1, namun pada data ini tidak dijelaskan keterangan musimnya, yang 3 musim apa, begitupun nilai lainnya, akan didapatkan keterangan lebih jelas jika nilai dari musimnya di ketahui.
# 2. Pada visualisasi data kedua didapatkan hasil sama pula, penggunaan yang terbanyak terdapat pada bulan 8 dengan jumlah sekitar 360.000
